# %%
#!/usr/bin/env python

# %load_ext autoreload
# %autoreload 2

import ipywidgets as widgets
from ipywidgets import interact, interact_manual
from IPython.display import display, HTML
import inspect
import os

from Dusty_Python import Dusty_Class
from Dusty_Python import Dusty_Widgets
from Dusty_Python import Object_Attribution
from Dusty_Python import AttributeStringArray
from Dusty_Python import FileWriter
from Dusty_Python import ExecuteButton

# %% [markdown]
# # Dusty Input

# %%
Dusty_Widgets.ShowWidgets()
ExecuteButton.Button()
# Out:
# HBox(children=(Label(value='Input File Name:'), Text(value='test1', placeholder='Name File')), layout=Layout(a…
# Tab(children=(VBox(children=(Label(value='External Radiation', layout=Layout(height='35px', margin='5px 0 10px…
# Button(button_style='success', description='Create Input File', layout=Layout(height='70px', margin='20px 0 30…
# Output(outputs=({'name': 'stdout', 'text': 'Error: One or more dropdowns are unselected. Please verify all cat…
