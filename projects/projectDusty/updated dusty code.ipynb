# %%
elements = np.array(w_sil_ow, w_sil_oc, w_sil_dl, w_grf_dl, w_amc_hn, w_sic_pg)

file.optical_depth = optical_depth.value
    if optical_depth.value == 1:
        for element in elements:
            file.chemical_comp = elements.value
        elements_list = chemicals_comp.value.split( , )
        file.CompArray(elements_list)

    if optical_depth.value == 2:
        for element in elements:
            file.chemical_comp = elements.value
        elements_list = chemicals_comp.value.split( , )
        file.CompArray(elements_list)
        file_list = mcc_file_tb.value.split( , )
        file.AddCompFiles(file_list)

    if optical_depth.value == 3:
        file.file = er_files.value

# %%
file.size_dstribution = size_distribution.value

components = np.array(power_index, lower_lim, upper_lim)
kmh_comp = np.array(kmh_power_index, kmh_lower_lim, kmh_characteristic_size)
    if size_distribution == 1:
        expo = 3.5,
        a_min = 0.005,
        a_max = 0.25

    if size_distribution == 2:
        for i in components
            file.modified_mrn = components.value
        modified_mrn_list = modified_mrn.value.split( , )
        file.CompArray(modified_mrn_list)

    if size_distribution == 3:
        for i in kmh_comp
            file.kmh = kmh_comp.value
        kmh_list = kmh_comp.value.split( , )
        file.CompArray(kmh_list)

# %%
w_sil_ow = widgets.FloatText(
    value=0.0,
    min=0,
    max=1.0,
    step=0.001,
    description='sil_ow:',
    disabled=False
)
w_sil_oc = widgets.FloatText(
    value=0.0,
    min=0,
    max=1.0,
    step=0.001,
    description='sil_oc:',
    disabled=False
)
w_sil_dl = widgets.FloatText(
    value=0.0,
    min=0,
    max=1.0,
    step=0.001,
    description='sil_dl:',
    disabled=False
)
w_grf_dl = widgets.FloatText(
    value=0.0,
    min=0,
    max=1.0,
    step=0.001,
    description='grf_dl:',
    disabled=False
)

elements_widgets = widgets.VBox([w_sil_ow, w_sil_oc, w_sil_dl, w_grf_dl, w_amc_hn, w_sic_pg])
display(element_widgets)

# %%
optical_depth = widgets.Dropdown(
    options = ['1', '2', '3'],
    value = '1',
    description='Choose:',
    disabled=False
)
display(optical_depth)

# %%
size_distribution= widgets.Dropdown(
    options = ['1', '2', '3'],
    value = '1',
    description='Choose:',
    disabled=False
)

display(size_distribution)

# %%
power_index = widgets.FloatText(    
    value=0.0,
    min=0,
    max=10000000000.0,
    step=0.001,
    description='modified MRN power index:',
    style={'description_width': 'auto'},
    disabled=False
)

lower_lim = widgets.FloatText(    
    value=0.0,
    min=0,
    max=1.0,
    step=0.001,
    description='lower limit a_min:',
    style={'description_width': 'auto'},
    disabled=False
)

upper_lim = widgets.FloatText(    
    value=0.0,
    min=0,
    max=10.0,
    step=0.001,
    description='upper limit a_max:',
    style={'description_width': 'auto'},
    disabled=False
)

mrn = widgets.VBox([power_index, lower_lim, upper_lim])

display(mrn)

# %%
kmh_power_index = widgets.FloatText(    
    value=0.0,
    min=0,
    max=100000000.0,
    step=0.001,
    description='KMH power index:',
    style={'description_width': 'auto'},
    disabled=False
)

kmh_lower_lim = widgets.FloatText(    
    value=0.0,
    min=0,
    max=1.0,
    step=0.001,
    description='lower limit a_min:',
    style={'description_width': 'auto'},
    disabled=False
)

kmh_characteristic_size = widgets.FloatText(    
    value=0.0,
    min=0,
    max=1.0,
    step=0.001,
    description='characteristic size:',
    style={'description_width': 'auto'},
    disabled=False
)

kmh = widgets.VBox([kmh_power_index, kmh_lower_lim, kmh_characteristic_size])

display(kmh)

# %%
inner_temp = widgets.FloatText(    
    value=0.0,
    min=0,
    max=10e20,
    step=0.01,
    description='boundary temp:',
    style={'description_width': 'auto'},
    disabled=False
)

display(inner_temp)
# Out:
# FloatText(value=0.0, description='boundary temp:', step=0.01, style=DescriptionStyle(description_width='auto')…
