# %%
# Checks current directory
# %pwd
# Out:
# '/home/jovyan/astr-302-w26_fork/lectures/lecture-07-jupyter'

# %%
# Use this to change to the proper directory if it's not connected properly
# %cd
# %cd astr-302-w26_fork/homeworks/submissions/hw2/Aria_Soh_HW2
# Out:
# /home/jovyan
# /home/jovyan/astr-302-w26_fork/homeworks/submissions/hw2/Aria_Soh_HW2

# %%
import visutils_soh as visutils

g, gr = visutils.load_and_prepare_cmd('fieldA.csv')
visutils.interactive_hess(g, gr)
# Out:
# interactive(children=(IntSlider(value=100, description='gridsize_val', max=300, min=50), Output()), _dom_class…
